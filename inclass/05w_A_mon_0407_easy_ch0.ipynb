# %% [markdown]
# <a href="https://colab.research.google.com/github/zziziz/2025-1-BDA/blob/main/inclass/05w_A_mon_0407_easy_ch0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##05주 수업

# %% [markdown]
# ##  05-3 파생변수 생성 p116

# %%
import pandas as pd
import pandas as pd
import numpy as np

df = pd.DataFrame({'var1' : [4, 3, 8], 'var2':[2, 6, 1]})
df
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df_raw = pd.DataFrame({'var1' : [1, 2, 1],
                       'var2' : [2, 3, 2],
                       'var3' : [10, 20, 30]})
df_raw
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df_new = df_raw.copy()
df_new
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
id(df_new) == id(df_raw)
# Out:
# False

# %%
df_new
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df_new.rename(columns = {'var2' : 'v2'}, inplace=True)
df_new
# Out:
#    var1  v2  var3
# 0     1   2    10
# 1     2   3    20
# 2     1   2    30

# %%
df_raw
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df_new.rename(index = {0: 'x', 1: 'y', 2: 'z'}, inplace=True)
df_new
# Out:
#    var1  v2  var3
# x     1   2    10
# y     2   3    20
# z     1   2    30

# %%
df = pd.DataFrame({"A": [1, 2, 3], "B": [4, 5, 6]})
df.rename(columns={"A": "a", "B":"c"})
# Out:
#    a  c
# 0  1  4
# 1  2  5
# 2  3  6
